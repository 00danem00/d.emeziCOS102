# %%
str = input("Enter your state of origin: ")

print("Your state of origin is: ", str)
print("The first character is: ", str[0])
print("The characters starting from 3rd to 5th are: ", str[2:5])
print("The string starting from 3rd character is: ", str[2:])
print("State of origin two times: ", str*2)
# Out:
# Enter your state of origin:  oyo
# Your state of origin is:  oyo
# The first character is:  o
# The characters starting from 3rd to 5th are:  o
# The string starting from 3rd character is:  o
# State of origin two times:  oyooyo

# %%
# input from user
m = float(input("enter mass in kilograms"))

#constant value for the speed of light in m/s
c = 299792458

#calculating energy using einstien's equation
energy = m*c**2

#displaying the result
print(f"\nThe energy equivalent to {m}kg of mass is {energy} joules.")
# Out:
# enter mass in kilograms 10
# The energy equivalent to 10.0kg of mass is 8.987551787368177e+17 joules.

# %%
list = ['anaconda', 786, 2.23, 'jupyter', 70.2]
shortlist = [321, 'python']

print(list)
print(list[0])
print(list[1:3])
print(list[2:])
print(shortlist * 2)
print(list + shortlist)
# Out:
# ['anaconda', 786, 2.23, 'jupyter', 70.2]
# anaconda
# [786, 2.23]
# [2.23, 'jupyter', 70.2]
# [321, 'python', 321, 'python']
# ['anaconda', 786, 2.23, 'jupyter', 70.2, 321, 'python']

# %%
tuple = ("ekiti", 750, 'oshogbo', 250, "akure", 500)
s_tuple = ("abeokuta", 300, "ogbomoso")

#prints the complete tuple
print(tuple)

#prints last element of the tuple
print(tuple[-1])

#prints elements of the tuple starting from 2nd till 3rd
print(tuple[2:4])

#prints elementsof the tuple starting from 3rd element
print(tuple[3:])

#prints the contents of the tuple twice
print(s_tuple * 2)

#prints concatenated tuples
print(tuple + s_tuple)
# Out:
# ('ekiti', 750, 'oshogbo', 250, 'akure', 500)
# 500
# ('oshogbo', 250)
# (250, 'akure', 500)
# ('abeokuta', 300, 'ogbomoso', 'abeokuta', 300, 'ogbomoso')
# ('ekiti', 750, 'oshogbo', 250, 'akure', 500, 'abeokuta', 300, 'ogbomoso')

# %%
#returns false as game_1 is not equal to game_2
game_1 = 2
game_2 = 4
print (bool(game_1 == game_2))
#or
print(game_1 == game_2)

#results false as vol is none
val = None
print(bool(val))

#returns false as num is an empty sequence
num = ()
print(bool(num))

#returns true as age is boolean
age = True
print(bool(age))
# Out:
# False
# False
# False
# False
# True

# %%
#convert to int

grade = int(70)         #grade will be 70
gpa = int(4.9)          #gpa will be 4.9
cgpa = int(4.6)        #cgpa will be 4

print (f"Grade = {grade}")
print (f"GPA = {gpa}")
print (f"CGPA = {cgpa}",)
# Out:
# Grade = 70
# GPA = 4
# CGPA = 4

# %%
#convert to float

grade = float(97)
gpa = float(5)
cgpa = float("4.7")

print(f"Grade = {grade}")
print(f"Grade")
